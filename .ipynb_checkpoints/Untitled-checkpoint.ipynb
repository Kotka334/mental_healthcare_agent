# %%
from openai import OpenAI
client = OpenAI(
    api_key="sk-live-eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJNZXRhQ2hhdCIsInN1YiI6IjY5M2ViY2YxODI1NDRmNGQ4NTJjNTVmNCIsImNsaWVudF9pZCI6IjA1MzYwZGU1ZGQ3NTNlMTdiOTg3ODE5NDdlZjUzYTY4Iiwic2NvcGUiOiJtaWRqb3VybmV5IGFnZW50IiwiaWF0IjoxNzY1NzE5NDY5fQ.SlE0KgwxnT3jTmDjZL402716VL2mL4LVNKLIhy0nWHo",
    base_url="https://llm-api.mmchat.xyz/v1"
)

completion = client.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {
            "role": "user",
            "content": "Write a one-sentence bedtime story about a unicorn."
        }
    ]
)

print(completion.choices[0].message.content)
# Out:
# Under a sky sprinkled with silver stars, a gentle unicorn tiptoed through a moonlit meadow, leaving a trail of dreams for every sleepy child.

# %%
pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 303.4 kB/s eta 0:00:02
#    ------------------- -------------------- 0.5/1.1 MB 303.4 kB/s eta 0:00:02
#    ------------------- -------------------- 0.5/1.1 MB 303.4 kB/s eta 0:00:02
# ...

# %%
pip install openai python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run app.py
# Out:
# 2025-12-15 01:39:17.995 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 01:39:17.996 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 01:39:17.996 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2025-12-15 01:39:17.997 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 01:39:17.997 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
